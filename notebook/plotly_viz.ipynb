# %% [markdown]
# # Visualization functions

# %%
import plotly.graph_objects as go

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load dataset

# %%
penguins_df = pd.read_csv("../ML_implementation/clustering_results.csv")

display(penguins_df.head())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen           39.10           18.7              181.0
# 1  Adelie  Torgersen           39.50           17.4              186.0
# 2  Adelie  Torgersen           40.30           18.0              195.0
# 3  Adelie  Torgersen           44.45           17.3              197.0
# 4  Adelie  Torgersen           36.70           19.3              193.0
#
#    body_mass_g      sex  bill_length_mm_outlier  bill_depth_mm_outlier  \
# 0       3750.0     Male                   False                  False
# 1       3800.0   Female                   False                  False
# 2       3250.0   Female                   False                  False
# 3       4050.0  Unknown                   False                  False
# 4       3450.0   Female                   False                  False
#
#    flipper_length_mm_outlier  body_mass_g_outlier  is_any_outlier  \
# ...

# %% [markdown]
# ## Correlation Heatmap

# %%
corr_matrix = penguins_df.select_dtypes(include="float").corr().round(2)
corr_fig = px.imshow(corr_matrix, 
                     color_continuous_scale="RdBu",
                     zmin=-1, 
                     zmax=1, 
                     text_auto=True)
corr_fig

# %% [markdown]
# ## Feature Histogram
# * Dropdown: Select attributes
# * Slider: Number of bins

# %%
def feat_histogram(df: pd.DataFrame, feature: str, nbins: int):
    fig = px.histogram(df, x=feature, nbins=nbins)
    return fig

# %% [markdown]
# ## Distribution
# * Tick box: Species(All, Adelie, Chinstrap, Gentoo)

# %%
def bar_species_island(df: pd.DataFrame):
    # Color theme
    color_map = {
        "Adelie": "darkorange",
        "Chinstrap": "purple",
        "Gentoo": "#008B8B"
    }

    count_df = df.groupby("island")["species"].value_counts().reset_index()
    count_df= count_df.sort_values(by="species")
    fig = px.bar(
        count_df, x="island", y="count", color="species",
        color_discrete_map = color_map
    )

    fig.update_layout(
        title={
            "text": ("Distribution of Species Among Islands<br>"
            "<span style='font-size:0.8em; color:gray;'>"
            "While Adele spreads across three islands, "
            "Chinstrap and Gentoo sticks to Dream and Biscoe respectively</span>"
        ),
        "x": 0
    }
    )
    return fig

# %%
bar_species_island(penguins_df)

# %% [markdown]
# ## Correlation
# * Tick box: Species in scatterplot (All, Adelie, Chinstrap, Gentoo)
# * Tick box: OLS (Yes, No)

# %%
def corr_flipper_body(df: pd.DataFrame):
    # Color theme
    color_map = {
        "Adelie": "darkorange",
        "Chinstrap": "purple",
        "Gentoo": "#008B8B"
    }
    
    fig = px.scatter(
        penguins_df,
        x="flipper_length_mm", y="body_mass_g",
        color="species", facet_col="island",
        color_discrete_map=color_map,
        trendline="ols",
        hover_data=['species', 'island', 'sex']
    )

    fig.update_layout(
        title={
            "text": ("Flipper Length and Body Mass Per Island<br>"
            "<span style='font-size:0.8em; color:gray;'>"
            "All species show a positive relationship, " \
        "with Adelie remaining consistent across islands, " \
        "indicating morphology is driven more by species than geography.</span>"
        ),
        "x": 0,
        "xanchor": "left"
    },
        margin=dict(t=100),
    )

    fig.update_layout(template="plotly_white")
    return fig

# %%
corr_flipper_body(penguins_df)

# %%
def corr_bill_body(df: pd.DataFrame):
    # Color theme
    color_map = {
        "Adelie": "darkorange",
        "Chinstrap": "purple",
        "Gentoo": "#008B8B"
    }
    
    fig = px.scatter(
        penguins_df,
        x="bill_area_mm2", y="body_mass_g",
        color="species", facet_col="island",
        color_discrete_map=color_map,
        trendline="ols",
        hover_data=['species', 'island', 'sex']
    )

    fig.update_layout(
        template="plotly_white",
        title={
            "text": ("Bill Area and Body Mass Per Island<br>"
            "<span style='font-size:0.8em; color:gray;'>"
            "All species show a positive relationship, " \
        "with Adelie remaining consistent across islands, " \
        "indicating morphology is driven more by species than geography</span>"
        ),
        "x": 0,
        "xanchor": "left"
        },
        margin=dict(t=100),
    )
    
    return fig

# %%
corr_bill_body(penguins_df)

# %% [markdown]
# ## How big is Body Mass to Bill Area

# %%
def box_body_bill_species(df):
    # Color theme
    color_map = {
        "Adelie": "darkorange",
        "Chinstrap": "purple",
        "Gentoo": "#008B8B"
    }
    
    df["mass_per_bill_area"] = (penguins_df["body_mass_g"] / (penguins_df["bill_length_mm"] * penguins_df["bill_depth_mm"]))

    fig = px.box(
        penguins_df,
        x="species",
        y="mass_per_bill_area",
        color="species",
        color_discrete_map={
        "Adelie": "darkorange",
        "Chinstrap": "purple",
        "Gentoo": "#008B8B"
        },
        title="Body Mass per Unit Bill Area by Species"
    )

    fig.update_layout(
    template="plotly_white",
    yaxis_title="Mass per Bill Area (g / mm²)"
    )

    return fig

# %%
box_body_bill_species(penguins_df)

# %%
def box_body_bill_island(df):
    # Color theme
    color_map = {
        "Adelie": "darkorange",
        "Chinstrap": "purple",
        "Gentoo": "#008B8B"
    }
    
    df["mass_per_bill_area"] = (penguins_df["body_mass_g"] / (penguins_df["bill_length_mm"] * penguins_df["bill_depth_mm"]))

    fig = px.box(
        penguins_df,
        x="island",
        y="mass_per_bill_area",
        color="island",
        color_discrete_map={
        "Adelie": "darkorange",
        "Chinstrap": "purple",
        "Gentoo": "#008B8B"
        },
        title="Body Mass per Unit Bill Area by Island"
    )

    fig.update_layout(
    template="plotly_white",
    yaxis_title="Mass per Bill Area (g / mm²)"
    )

    return fig

# %%
box_body_bill_island(penguins_df)

# %% [markdown]
# ## Simpson's paradox when omitting the species variable
# Expected: Filter general vs each species

# %%
def bill_length_depth(df: pd.DataFrame):
    
    fig = px.scatter(
        penguins_df,
        x="bill_length_mm", y="bill_depth_mm",
        hover_data=['species', 'island', 'sex'],
        color_discrete_sequence=["black"], trendline="ols",
        title="Penguin bills dimension"
    )

    fig.update_layout(template="plotly_white")
    return fig

# %%
bill_length_depth(penguins_df)

# %%
def bill_length_depth(df: pd.DataFrame):
    color_map = {
        "Adelie": "darkorange",
        "Chinstrap": "purple",
        "Gentoo": "#008B8B"
    }
    
    fig = px.scatter(
        penguins_df,
        x="bill_length_mm", y="bill_depth_mm",
        color="species", trendline="ols",
        color_discrete_map=color_map, 
        hover_data=['species', 'island', 'sex'],
        title="Penguin bills dimension"
    )

    fig.update_layout(template="plotly_white")
    return fig

# %%
bill_length_depth(penguins_df)

# %% [markdown]
# ## Ground truth labels

# %%
def plot_pca_clusters(df):
    fig = px.scatter(
        df,
        x='PC1',
        y='PC2',
        color='cluster',
        hover_data=['species', 'island', 'sex'],
    )
    return fig

plot_pca_clusters(penguins_df)

# %%
def plot_pca_species(df):
    fig = px.scatter(
        df,
        x='PC1',
        y='PC2',
        color='species',
        title="Ground Truth (Species)"
    )

    return fig
plot_pca_species(penguins_df)

# %% [markdown]
# Based on the clustering results, we can infer cluster 0 = Adelie, cluster 1 = Gentoo, and cluster 2 = Chinstrap.

# %%
cluster_map = {
    0: "Adelie",
    1: "Gentoo",
    2: "Chinstrap"
}

penguins_df["cluster_label"] = penguins_df["cluster"].map(cluster_map)
penguins_df["is_mismatch"] = penguins_df["cluster_label"] != penguins_df["species"]

# %%
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen           39.10           18.7              181.0
# 1    Adelie  Torgersen           39.50           17.4              186.0
# 2    Adelie  Torgersen           40.30           18.0              195.0
# 3    Adelie  Torgersen           44.45           17.3              197.0
# 4    Adelie  Torgersen           36.70           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe           44.45           17.3              197.0
# 340  Gentoo     Biscoe           46.80           14.3              215.0
# 341  Gentoo     Biscoe           50.40           15.7              222.0
# 342  Gentoo     Biscoe           45.20           14.8              212.0
# 343  Gentoo     Biscoe           49.90           16.1              213.0
#
#      body_mass_g      sex  bill_length_mm_outlier  bill_depth_mm_outlier  \
# ...

# %%
def plot_pca_clusters(df):
    fig = px.scatter(
        df,
        x='PC1',
        y='PC2',
        color='cluster_label',
        symbol='is_mismatch',  # 👈 key
        symbol_map={
            False: "circle",
            True: "x"
        },
        color_discrete_map={
            "Adelie": "darkorange",
            "Chinstrap": "purple",
            "Gentoo": "#008B8B"
        },
        title="PCA Clusters vs Ground Truth"
    )
    return fig

# %%
plot_pca_clusters(penguins_df)
